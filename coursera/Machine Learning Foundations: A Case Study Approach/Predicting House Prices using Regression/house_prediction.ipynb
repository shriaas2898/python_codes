# %% [markdown]
# # Launch Turi Create

# %%
import turicreate

# %% [markdown]
# # Load house sales data

# %%
sales_sf = turicreate.SFrame('home_data.sframe/')

# %%
sales_sf
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900.0 |   3.0    |    1.0    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000.0 |   3.0    |    2.25   |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000.0 |   2.0    |    1.0    |
# | 2487200875 | 2014-12-09 00:00:00+00:00 |  604000.0 |   4.0    |    3.0    |
# ...

# %% [markdown]
# # Exploring the data for housing sales

# %%
sales_sf.show()
# Out:
# Materializing SFrame
# ...
# Further warnings of unsupported type will be suppressed.
# ...

# %%
turicreate.show(sales_sf[1:5000]['sqft_living'],sales_sf[1:5000]['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# # Simple regression model that predicts price from square feet

# %%
#Spliting data randomly to training and testing set
training_set, test_set = sales_sf.random_split(.8,seed=0)
#First argument of random_split function is perecentage 
#of data to be used as training data. In this case 80%
#seed could be any number which denotes the random combibation

# %% [markdown]
# ## Train simple regression model

# %%
sqft_model = turicreate.linear_regression.create(training_set,target='price',features=['sqft_living'])
#target argument denotes the y or the variable you are trying to predict
#features is the list of features used for prediction
#By default features use all the columns
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 1
# Number of unpacked features : 1
# Number of coefficients    : 2
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Evaluate the quality of our model

# %%
print (test_set['price'].mean())
# Out:
# 543054.0425632532

# %%
print (sqft_model.evaluate(test_set))
#rmse = root mean square
# Out:
# {'max_error': 4132665.98266148, 'rmse': 255227.74244184917}

# %% [markdown]
# # Explore model a little further

# %%
sqft_model.coefficients
# Out:
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 2
#
# Data:
# +-------------+-------+---------------------+--------------------+
# |     name    | index |        value        |       stderr       |
# +-------------+-------+---------------------+--------------------+
# | (intercept) |  None | -50158.091916409554 | 5065.193035407509  |
# | sqft_living |  None |  283.36623956066023 | 2.2253499707489666 |
# +-------------+-------+---------------------+--------------------+
# [2 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(test_set['sqft_living'],test_set['price'],'.',
        test_set['sqft_living'],sqft_model.predict(test_set),'-')

# %% [markdown]
# # Explore other features of the data

# %%
my_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors','zipcode']

# %%
sales_sf[my_features].show()
# Out:
# Materializing SFrame
# ...

# %%
turicreate.show(sales_sf['zipcode'],sales_sf['price'])
# Out:
# Materializing X axis SArray
# Materializing Y axis SArray
# ...

# %% [markdown]
# # Build a model with these additional features

# %%
my_features_model = turicreate.linear_regression.create(training_set,target='price',features=my_features)
# Out:
# PROGRESS: Creating a validation set from 5 percent of training data. This may take a while.
#           You can set ``validation_set=None`` to disable validation tracking.
# Linear regression:
# --------------------------------------------------------
# Number of examples          : 16514
# Number of features          : 6
# Number of unpacked features : 6
# Number of coefficients    : 75
# Starting Newton Method
# --------------------------------------------------------
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# | Iteration | Passes   | Elapsed Time | Training Max Error | Validation Max Error | Training Root-Mean-Square Error | Validation Root-Mean-Square Error |
# +-----------+----------+--------------+--------------------+----------------------+---------------------------------+-----------------------------------+
# ...

# %% [markdown]
# # Compare simple model with more complex one

# %%
print (my_features)
my_features_model.coefficients
# Out:
# ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
# Columns:
# 	name	str
# 	index	str
# 	value	float
# 	stderr	float
#
# Rows: 75
#
# Data:
# +-------------+-------+---------------------+----------------------+
# |     name    | index |        value        |        stderr        |
# +-------------+-------+---------------------+----------------------+
# | (intercept) |  None |  -6757.457427039859 |  14423.574372152096  |
# |   bedrooms  |  None |  -51670.40765024233 |  2103.6379433924617  |
# |  bathrooms  |  None |  16184.141539992586 |  3247.157709429904   |
# | sqft_living |  None |  278.8221229743413  |  2.7934766878593096  |
# |   sqft_lot  |  None | 0.25896380410890685 | 0.039590412076382336 |
# |    floors   |  None |  -18076.00264585151 |  3359.3727476850763  |
# |   zipcode   | 98028 |  41095.621146490375 |  18468.230003706794  |
# |   zipcode   | 98136 |  225375.80377075146 |  18482.65642045593   |
# ...

# %%
print (sqft_model.evaluate(test_set))
print (my_features_model.evaluate(test_set))
# Out:
# {'max_error': 4132665.98266148, 'rmse': 255227.74244184917}
# {'max_error': 3147583.081450966, 'rmse': 180590.08167460668}

# %% [markdown]
# # Apply learned models to make predictions

# %%
house1 = sales_sf[sales_sf['id']=='5309101200']

# %%
house1
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+----------+----------+-----------+
# |     id     |            date           |  price   | bedrooms | bathrooms |
# +------------+---------------------------+----------+----------+-----------+
# | 5309101200 | 2014-06-05 00:00:00+00:00 | 620000.0 |   4.0    |    2.25   |
# +------------+---------------------------+----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="http://blue.kingcounty.com/Assessor/eRealProperty/MediaHandler.aspx?Media=2916871">

# %%
print (house1['price'])
# Out:
# [620000.0, ... ]

# %%
print (sqft_model.predict(house1))
# Out:
# [629920.883029175]

# %%
print (my_features_model.predict(house1))
# Out:
# [724495.9972504767]

# %% [markdown]
# ## Prediction for a second house, a fancier one

# %%
house2 = sales[sales['id']=='1925069082']

# %%
house2
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	float
# 	bedrooms	float
# 	bathrooms	float
# 	sqft_living	float
# 	sqft_lot	float
# 	floors	float
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	float
# 	sqft_above	float
# 	sqft_basement	float
# 	yr_built	float
# 	yr_renovated	float
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+-----------+----------+-----------+
# |     id     |            date           |   price   | bedrooms | bathrooms |
# +------------+---------------------------+-----------+----------+-----------+
# | 1925069082 | 2015-05-11 00:00:00+00:00 | 2200000.0 |   5.0    |    4.25   |
# +------------+---------------------------+-----------+----------+-----------+
# +-------------+----------+--------+------------+------+-----------+-------+
# | sqft_living | sqft_lot | floors | waterfront | view | condition | grade |
# ...

# %% [markdown]
# <img src="https://ssl.cdn-redfin.com/photo/1/bigphoto/302/734302_0.jpg">

# %%
print (sqft_model.predict(house2))
# Out:
# [1264661.259645054]

# %%
print (my_features_model.predict(house2))
# Out:
# [1237195.165245315]

# %% [markdown]
# ## Prediction for a super fancy home

# %%
bill_gates = {'bedrooms':[8], 
              'bathrooms':[25], 
              'sqft_living':[50000], 
              'sqft_lot':[225000],
              'floors':[4], 
              'zipcode':['98039'], 
              'condition':[10], 
              'grade':[10],
              'waterfront':[1],
              'view':[4],
              'sqft_above':[37500],
              'sqft_basement':[12500],
              'yr_built':[1994],
              'yr_renovated':[2010],
              'lat':[47.627606],
              'long':[-122.242054],
              'sqft_living15':[5000],
              'sqft_lot15':[40000]}

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/2/26/Residence_of_Bill_Gates.jpg">

# %%
print (my_features_model.predict(turicreate.SFrame(bill_gates)))
# Out:
# [15110798.017556941]

# %%
print (sqft_model.predict(turicreate.SFrame(bill_gates)))
# Out:
# [14118153.886116602]
